# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split

# %%
# 경로 설정
path = "./drive/MyDrive/colab/ML_lab/"
file = path+"lab3_test.csv"

# 전체 파일을 읽어 전체 샘플의 개수와 각 샘플의 크기를 파악
df = pd.read_csv(file, header=None)
total_number_of_sample = len(df)
sample_size = len(df.columns)

# 마지막 열을 label로, 나머지 열들을 feature로 하여 분리
x_data_cols = [i for i in range(sample_size - 1)]
y_data_cols = [sample_size - 1]
x_data = pd.read_csv(file, header=None, usecols=x_data_cols).values
y_data = pd.read_csv(file, header=None, usecols=y_data_cols).values.reshape(-1,)

# 데이터를 train set : test set = 3 : 1 비율로 나눔
x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, random_state=0)

# %%
start = 1
last = total_number_of_sample // 3
interval = 5

print(f"== interval: {interval} ==")
print("k: ACC")

for i in range(start, last, interval):
  knn = KNeighborsClassifier(n_neighbors=i)
  knn.fit(x_train, y_train)
  y_pred = knn.predict(x_test)
  print(str(i)+": {:.3f}".format(np.mean(y_pred == y_test)))
# Out:
# == interval: 5 ==
# k: ACC
# 1: 0.974
# 6: 0.974
# 11: 0.974
# 16: 0.974
# 21: 0.974
# 26: 0.947
# 31: 0.947
# 36: 0.947
# 41: 0.895
# 46: 0.895
